# %% [markdown]
# <a href="https://colab.research.google.com/github/rajeshwarisubramani/langchain01/blob/main/Distilgpt2Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-xl")
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-xl")

input_text = "translate English to German: How old are you?"
input_ids = tokenizer(input_text, return_tensors="pt").input_ids

outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/558 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# <pad> Wie alt sind Sie?</s>

# %%
from transformers import pipeline

# Load the model using pipeline (handles tokenizer + model automatically)
translator = pipeline("text-generation", model="distilgpt2")

# Run translation
result = translator("translate English to German: How old are you?")

print(result[0]["generated_text"])
# Out:
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# translate English to German: How old are you?

# %%
print(result[0])
# Out:
# {'generated_text': 'translate English to German: How old are you?\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}

# %%
def show(title: str, prompt: str, results: list, notes: str = ""):
    print("─" * 62)
    print(f"  {title}")
    if notes:
        print(f"  ℹ️  {notes}")
    print("─" * 62)
    print(f"  Prompt : \"{prompt}\"")
    for i, r in enumerate(results, 1):
        label = f"  Seq {i}  : " if len(results) > 1 else "  Output : "
        print(f"{label}{r['generated_text']}")
    print()

# %%
show(
    title  = "TEST 1 │ Baseline Prompt",
    prompt = "AI is transforming industries by",
    results= translator(
        "AI is transforming industries by",
        max_length=40,
        num_return_sequences=1
    )
)
# Out:
# Passing `generation_config` together with generation-related arguments=({'max_length', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ──────────────────────────────────────────────────────────────
#   TEST 1 │ Baseline Prompt
# ──────────────────────────────────────────────────────────────
#   Prompt : "AI is transforming industries by"
#   Output : AI is transforming industries by creating new strategies for improving customer service. The most recent report on the success of the online payment platform, Money in the City, reveals that while the success of the online payment platform was not an indication of the future of the online payment platform, it is a reflection of how the business model has changed.
#
#
#
# "In the past year, we have seen a few new entrants like Paypal, and we have seen a few new entrants like Paypal, and we have seen a few new entrants like Paypal, and we have seen a few new entrants like Paypal, and we have seen a few new entrants like Paypal, and we have seen a few new entrants like Paypal, and we have seen a few new entrants like Paypal, and we have seen a few new entrants like Paypal, and we have seen a few new entrants like Paypal, and we have seen a few new entrants like Paypal, and we have seen a few new entrants like Paypal, and we have seen a few new entrants like Paypal, and we have seen a few new entrants like Paypal, and we have seen a few new entrants like Paypal, and we have seen a few new entrants like Paypal, and we have seen a few

# %%
# ============================================================
#   DistilGPT-2 Text Generation Explorer
#   Run:  python distilgpt2_explorer.py
#   Requires: pip install transformers torch
# ============================================================

# ── Step 0 · Install dependencies (uncomment if needed) ─────
# import subprocess, sys
# subprocess.run([sys.executable, "-m", "pip", "install",
#                 "transformers", "torch", "--quiet"])

import warnings
warnings.filterwarnings("ignore")

from transformers import pipeline, AutoTokenizer

# ════════════════════════════════════════════════════════════
#  LOAD MODEL
# ════════════════════════════════════════════════════════════
print("=" * 62)
print("  DistilGPT-2 Text Generation Explorer")
print("=" * 62)
print("\n⏳ Loading distilgpt2 …  (downloads ~80 MB on first run)\n")

generator = pipeline("text-generation", model="distilgpt2")

print("✅ Model loaded!\n")

# ════════════════════════════════════════════════════════════
#  HELPER — pretty-print results
# ════════════════════════════════════════════════════════════
def show(title: str, prompt: str, results: list, notes: str = ""):
    print("─" * 62)
    print(f"  {title}")
    if notes:
        print(f"  ℹ️  {notes}")
    print("─" * 62)
    print(f"  Prompt : \"{prompt}\"")
    for i, r in enumerate(results, 1):
        label = f"  Seq {i}  : " if len(results) > 1 else "  Output : "
        print(f"{label}{r['generated_text']}")
    print()


# ════════════════════════════════════════════════════════════
#  TEST 1 · Baseline (from the assignment)
# ════════════════════════════════════════════════════════════
show(
    title  = "TEST 1 │ Baseline Prompt",
    prompt = "AI is transforming industries by",
    results= generator(
        "AI is transforming industries by",
        max_length=40,
        num_return_sequences=1
    )
)

# ════════════════════════════════════════════════════════════
#  TEST 2 · Different topic — observe domain shift in output
# ════════════════════════════════════════════════════════════
show(
    title  = "TEST 2 │ Different Topic Prompt",
    prompt = "The future of medicine depends on",
    results= generator(
        "The future of medicine depends on",
        max_length=40,
        num_return_sequences=1
    ),
    notes  = "Same params, different topic → output changes direction"
)

# ════════════════════════════════════════════════════════════
#  TEST 3 · Vary max_length → see how output truncates / grows
# ════════════════════════════════════════════════════════════
prompt3 = "Space exploration will lead to"
print("─" * 62)
print("  TEST 3 │ Varying max_length (20 vs 60 tokens)")
print("  ℹ️  Watch how the story grows as we allow more tokens")
print("─" * 62)
print(f"  Prompt : \"{prompt3}\"")

r_short = generator(prompt3, max_length=20,  num_return_sequences=1)
r_long  = generator(prompt3, max_length=60,  num_return_sequences=1)

print(f"  max=20  : {r_short[0]['generated_text']}")
print(f"  max=60  : {r_long[0]['generated_text']}")
print()

# ════════════════════════════════════════════════════════════
#  TEST 4 · Multiple sequences — diversity in one call
# ════════════════════════════════════════════════════════════
show(
    title  = "TEST 4 │ Multiple Sequences (num_return_sequences=3)",
    prompt = "Robots will soon be able to",
    results= generator(
        "Robots will soon be able to",
        max_length=35,
        num_return_sequences=3,
        do_sample=True,
        temperature=0.9
    ),
    notes  = "Three different continuations from the same prompt"
)

# ════════════════════════════════════════════════════════════
#  TEST 5 · Temperature — focused (0.3) vs creative (1.5)
# ════════════════════════════════════════════════════════════
prompt5 = "Deep learning models can"
print("─" * 62)
print("  TEST 5 │ Temperature Effect (do_sample=True)")
print("  ℹ️  Low temp = repetitive/safe. High temp = wild/creative.")
print("─" * 62)
print(f"  Prompt : \"{prompt5}\"")

r_low  = generator(prompt5, max_length=40, num_return_sequences=1,
                   do_sample=True, temperature=0.3)
r_high = generator(prompt5, max_length=40, num_return_sequences=1,
                   do_sample=True, temperature=1.5)

print(f"  temp=0.3: {r_low[0]['generated_text']}")
print(f"  temp=1.5: {r_high[0]['generated_text']}")
print()

# ════════════════════════════════════════════════════════════
#  TEST 6 · Greedy vs Sampling (do_sample flag)
# ════════════════════════════════════════════════════════════
prompt6 = "The best way to learn programming is"
print("─" * 62)
print("  TEST 6 │ Greedy Decoding vs Random Sampling")
print("  ℹ️  Greedy always picks the highest-prob token → deterministic")
print("─" * 62)
print(f"  Prompt : \"{prompt6}\"")

r_greedy  = generator(prompt6, max_length=40, do_sample=False)   # greedy
r_sampled = generator(prompt6, max_length=40, do_sample=True, temperature=1.0)

print(f"  greedy  : {r_greedy[0]['generated_text']}")
print(f"  sampled : {r_sampled[0]['generated_text']}")
print()

# ════════════════════════════════════════════════════════════
#  TEST 7 · Tokenisation deep-dive
# ════════════════════════════════════════════════════════════
print("─" * 62)
print("  TEST 7 │ Tokenisation Peek")
print("  ℹ️  Words ≠ tokens. GPT-2 uses Byte-Pair Encoding (BPE).")
print("─" * 62)

tokenizer = AutoTokenizer.from_pretrained("distilgpt2")

sentences = [
    "AI is transforming industries by automating tasks",
    "Unbelievably, transformers revolutionised NLP overnight!",
]

for sentence in sentences:
    token_ids = tokenizer.encode(sentence)
    tokens    = [tokenizer.decode([t]) for t in token_ids]
    print(f"\n  Sentence  : {sentence}")
    print(f"  Token IDs : {token_ids}")
    print(f"  Tokens    : {tokens}")
    print(f"  Stats     : {len(sentence.split())} words → {len(token_ids)} tokens")

print()

# ════════════════════════════════════════════════════════════
#  SUMMARY TABLE
# ════════════════════════════════════════════════════════════
print("=" * 62)
print("  WHAT TO OBSERVE — Key Takeaways")
print("=" * 62)
summary = [
    ("max_length ↑",         "Longer output; model may drift off-topic"),
    ("num_return_sequences↑","Multiple diverse completions in one call"),
    ("temperature ↓ (0.1)",  "Safe, repetitive, predictable text"),
    ("temperature ↑ (1.5)",  "Creative, sometimes incoherent text"),
    ("do_sample=False",      "Greedy — same output every run"),
    ("do_sample=True",       "Stochastic — different each time"),
    ("Tokenisation",         "Subword tokens, not whole words (BPE)"),
]
print(f"  {'Parameter':<28} {'Effect'}")
print("  " + "-" * 56)
for param, effect in summary:
    print(f"  {param:<28} {effect}")
print("=" * 62)
print("  ✅  All tests complete!")
print("=" * 62)
# Out:
# ==============================================================
#   DistilGPT-2 Text Generation Explorer
# ==============================================================
#
# ⏳ Loading distilgpt2 …  (downloads ~80 MB on first run)
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ✅ Model loaded!
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ──────────────────────────────────────────────────────────────
#   TEST 1 │ Baseline Prompt
# ──────────────────────────────────────────────────────────────
#   Prompt : "AI is transforming industries by"
#   Output : AI is transforming industries by transforming their industries and services.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ──────────────────────────────────────────────────────────────
#   TEST 2 │ Different Topic Prompt
#   ℹ️  Same params, different topic → output changes direction
# ──────────────────────────────────────────────────────────────
#   Prompt : "The future of medicine depends on"
#   Output : The future of medicine depends on the question of 'the right to life' and the role of the government in developing the world. The question will be answered when we know what we need to do to improve the quality of life of the people of the world.
#
# ──────────────────────────────────────────────────────────────
#   TEST 3 │ Varying max_length (20 vs 60 tokens)
#   ℹ️  Watch how the story grows as we allow more tokens
# ──────────────────────────────────────────────────────────────
#   Prompt : "Space exploration will lead to"
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Passing `generation_config` together with generation-related arguments=({'temperature', 'do_sample', 'max_length', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=35) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#   max=20  : Space exploration will lead to an ever-more affordable solar system that delivers a cleaner energy source.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   max=60  : Space exploration will lead to the development of the next generation of aircraft, including a new generation of fighters, and a new generation of fighter aircraft.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ──────────────────────────────────────────────────────────────
#   TEST 4 │ Multiple Sequences (num_return_sequences=3)
#   ℹ️  Three different continuations from the same prompt
# ──────────────────────────────────────────────────────────────
#   Prompt : "Robots will soon be able to"
#   Seq 1  : Robots will soon be able to set up a network of apps, from which they can access a realtime data stream for data-rich user-generated data.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   Seq 2  : Robots will soon be able to display a full-body version of a robotic-inspired robot, with all the latest software and tools built-in to make their voices stronger.
#
#
#
# The robots will then be able to take a walk, climb stairs, walk through a landscape and navigate the forest.
# The robot will also have a unique ability to be programmed to run through the environment and control its own robots.
# But the company is still in negotiations with China about its plans for a robotic-friendly version.
# The company has yet to formally reveal an official timeframe.
# The company also said the company is still working with Taiwan to develop a robot that could also be made from fiberglass.
# The technology could be used to walk a distance, with the help of human intelligence, and other technology.
# The device could also be used to carry around a train and other personal items.
# However, the latest developments in the "Robots of the Future" project indicate the company is already thinking of putting an end to a "supercharge" in its robot development process.
# The robot is currently "under construction" at a company that is already working with Chinese and Chinese companies.
#   Seq 3  : Robots will soon be able to perform certain tasks:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# E1 1 10 20
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# E1 10 30
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────
#   TEST 5 │ Temperature Effect (do_sample=True)
#   ℹ️  Low temp = repetitive/safe. High temp = wild/creative.
# ──────────────────────────────────────────────────────────────
#   Prompt : "Deep learning models can"
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Passing `generation_config` together with generation-related arguments=({'do_sample', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#   temp=0.3: Deep learning models can help us to understand and understand the world around us.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   temp=1.5: Deep learning models can enhance its knowledge about real or fake information due to algorithms and naturalist analyses of historical time patterns.
#
#
# The models show that there does not need to be an algorithm for understanding real or fake information, to be able to measure accurately, to detect real data, to understand complex interactions between different populations. But these model-inspired simulations offer insights that researchers in both medical and business organizations do not always follow. The model that a citizen can find has an advantage which not only has an even lower accuracy and has more accuracy — and therefore, it has more time to refine its understanding of global climate and other phenomena such as climate change.
# To gain a better understanding of whether we now see artificial intelligence and social networks as tools for better understanding human relationships — through direct scientific or naturalist reviews into real information on people such as usets, computers at different time groups — scientists can use predictive models and algorithms that give us an intuitive understanding of the real world and other processes being studied.
# Because of its complexity, the model could be used to determine what people experience as individuals in that human presence through their interaction with different cultural groups rather than with human-related causes or institutions in that environment and to compare their results with real patterns in reality, with further analysis of this possible
#
# ──────────────────────────────────────────────────────────────
#   TEST 6 │ Greedy Decoding vs Random Sampling
#   ℹ️  Greedy always picks the highest-prob token → deterministic
# ──────────────────────────────────────────────────────────────
#   Prompt : "The best way to learn programming is"
# Passing `generation_config` together with generation-related arguments=({'temperature', 'do_sample', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#   greedy  : The best way to learn programming is to learn from the experience of the programmer.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   sampled : The best way to learn programming is to find a programming mentor that you are willing to work with over the past couple of months…
#
#
#
# Here's the latest interview: Chris Gattison, CEO
# Chris Gattison, CEO of the new programming platform, a startup that specializes in learning programming. Chris Gattison founded the project, and is now responsible for managing sales, development & testing for the new platform.
# What would you like to see developers create and build to build your own programming products?
# I think one of the big challenges is you have to look at all the people that you can work with. They've done stuff that they've worked on before they can find the people they want to work with. Now you're only dealing with an individual from different platforms, so sometimes, they're all doing what you're trying to do.
# Chris Gattison has sold off the original platform, the new development platform, and it's a great platform, it's good for everyone there. I think the hardest part—and it's going to help improve it a lot.
# Chris Gattison runs the Free Programming Language and the other open source software that the company is using. In the meantime, there are over 700 programming languages on Stack Overflow, and its more
#
# ──────────────────────────────────────────────────────────────
#   TEST 7 │ Tokenisation Peek
#   ℹ️  Words ≠ tokens. GPT-2 uses Byte-Pair Encoding (BPE).
# ──────────────────────────────────────────────────────────────
#
#   Sentence  : AI is transforming industries by automating tasks
#   Token IDs : [20185, 318, 25449, 11798, 416, 3557, 803, 8861]
#   Tokens    : ['AI', ' is', ' transforming', ' industries', ' by', ' autom', 'ating', ' tasks']
#   Stats     : 7 words → 8 tokens
#
#   Sentence  : Unbelievably, transformers revolutionised NLP overnight!
#   Token IDs : [3118, 6667, 11203, 1346, 11, 6121, 364, 5854, 1417, 399, 19930, 13417, 0]
#   Tokens    : ['Un', 'bel', 'iev', 'ably', ',', ' transform', 'ers', ' revolution', 'ised', ' N', 'LP', ' overnight', '!']
#   Stats     : 5 words → 13 tokens
#
# ==============================================================
#   WHAT TO OBSERVE — Key Takeaways
# ==============================================================
#   Parameter                    Effect
#   --------------------------------------------------------
#   max_length ↑                 Longer output; model may drift off-topic
#   num_return_sequences↑        Multiple diverse completions in one call
#   temperature ↓ (0.1)          Safe, repetitive, predictable text
#   temperature ↑ (1.5)          Creative, sometimes incoherent text
#   do_sample=False              Greedy — same output every run
#   do_sample=True               Stochastic — different each time
#   Tokenisation                 Subword tokens, not whole words (BPE)
# ==============================================================
#   ✅  All tests complete!
# ==============================================================
